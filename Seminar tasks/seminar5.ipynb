# %% [markdown]
# # Основы программирования в Python
#
# *Алла Тамбовцева и Светлана Жучкова, НИУ ВШЭ*
#
# ## Семинар 7

# %% [markdown]
# ### Задача 1
# Напишите функцию `square()`, которая принимает на вход число и:
#
# * возвращает его квадрат;
# * выводит на экран сообщение вида "Квадрат числа равен: n" и ничего не возвращает;
# * выводит на экран сообщение вида "Квадрат числа равен: n" и возвращает квадрат числа;
# * выводит на экран сообщение вида "Квадрат числа равен: n" или же "Неверный формат входных данных", если на вход функции подана строка, а не число.

# %% [markdown]
# ### Задача 2
# Напишите функцию `nums()`, которая принимает на вход целое число, а возвращает список из двух элементов: целое число, предшествующее принятому на вход, и число, следующее за ним, в виде списка.
#
# **Пример:**
#
# *Входные данные:*
#
#     7
#
# *Выходные данные:*
#
#     [6, 8]

# %% [markdown]
# ### Задача 3
# Напишите функцию `str_lower()`, которая принимает на вход строку (набор слов через пробел) и возвращает список её элементов (слов) в нижнем регистре.
# Добавьте к функции аргумент, с помощью которого можно выбрать, в каком виде возвращать данные - в виде строки или в виде списка (сделайте так, чтобы по умолчанию данные возвращались в виде списка).
#
# **Пример:**
#
# *Входные данные:*
#
#     "В лесу родилась ёлочка В лесу она росла"
#
# *Выходные данные:*
#
#     ['в', 'лесу', 'родилась', 'ёлочка', 'в', 'лесу', 'она', 'росла']

# %% [markdown]
# ### Задача 4
# Напишите функцию `my_log()`, которая принимает на вход список чисел, и возвращает список их натуральных логарифмов. Если число меньше или равно 0, на его месте в возвращаемом списке должно быть None. Попробуйте решить эту задачу двумя способами:
# 1. используя цикл *for* и конструкцию *try-except*,
# 2. используя *list comprehension* с условиями внутри
#
# **Пример:**
#
# *Входные данные:*
#
#     [1, 3, 2.5, -1, 9, 0, 2.71]
#
# *Выходные данные:*
#
#     [0.0,
#      1.0986122886681098,
#      0.9162907318741551,
#      None,
#      2.1972245773362196,
#      None,
#      0.9969486348916096]

# %% [markdown]
# ### Задача 5
# Напишите функцию, которая принимает на вход два списка (имена людей и их возраст) и делает следующее:
#
# * если в списках одинаковое количество элементов, то возвращает словарь с парами имя-возраст;
#
# * если в списках разное количество элементов, то функция выводит на экран сообщение "Списки имеют разную длину" и возвращает пустой словарь.
#
# **Пример:**
#
# *Входные данные:*
#
#     ["Ann", "Tim", "Sam"]
#     [12, 23, 17]
#
# *Выходные данные:*
#
#     {"Ann": 12, "Tim": 23, "Sam": 17}
#
# *Входные данные:*
#
#     ["Ann", "Tim", "Sam"]
#     [12, 23, 17, 45]
#
# *Выходные данные:*
#
#     Списки имеют разную длину
#     {}

# %% [markdown]
# ### Задача 6
#
# Напишите функцию `all_sort()`, которая принимает на вход перечень целых чисел через запятую (не список, а просто сколько угодно значений через запятую) и возвращает список этих значений, отсортированный по возрастанию.
# Добавьте в свою функцию следующее: если по ошибке наряду с числовыми значениями вводится строка, функция должна выводить на экран фразу: "Введён неверный формат данных".
#
# **Пример:**
#
# *Входные данные:*
#
#     7, 6, 1, 3, 8, 0, -2
#
# *Выходные данные:*
#
#     [-2, 0, 1, 3, 6, 7, 8]

# %% [markdown]
# ### Задача 7 (сложная)
#
# Напишите функцию `modify_list(lst)`, которая принимает на вход список целых чисел, удаляет из него все нечётные значения, а чётные нацело делит на два. Функция не должна ничего возвращать, требуется только изменение переданного списка, например:
#
# ```python
# lst = [1, 2, 3, 4, 5, 6]
# print(modify_list(lst))  # None
# print(lst)               # [1, 2, 3]
# modify_list(lst)
# print(lst)               # [1]
#
# lst = [10, 5, 8, 3]
# modify_list(lst)
# print(lst)               # [5, 4]
# ```

# %% [markdown]
# ### Задача 8 (лёгкая, уже было на семинаре по циклам)
#
# Напишите функцию `remove_double_spaces(text)`, которая принимает на вход строку с текстом, в котором присутствуют двойные пробелы, удаляет все двойные пробелы (оставляет корректный вариант - один пробел между словами) и возвращает исправленный вариант. Лишних одинарных пробелов по краям текста быть не должно.

# %% [markdown]
# ### Задача 9 (моя любимая, из прошлогодней контрольной)
#
# Несколько лет назад, когда интернет только начал активно проникать в нашу жизнь, было модно писать сообщения "заборчиком", то есть какие-то буквы в сообщении писать в верхнем регистре, а какие-то - в нижнем. Например, не `привет`, а `ПрИвЕт`. Напишите функцию `my_swapcase(word)`, которая принимает на вход одно слово на русском языке в нижнем регистре и возвращает его, написанное "заборчиком", согласно следующему правилу: если буква стоит на чётной позиции или же эта буква - гласная, то она пишется в верхнем регистре, в любом другом случае - в нижнем. Чётная позиция в данном случае - это чётная позиция в понимании Python (элементы с индексами 0, 2, 4 и т.д.).
#
# Список гласных букв русского алфавита: `аоеяуиюэёы`.
#
# *Подсказка: не пытайтесь изменять аргумент функции с введённым словом (строки, как вы помните, не изменяемы) - вместо этого создайте пустую строку и наполняйте её нужными символами.*
#
# **Пример:**
#
#     my_swapcase(рождение)
#
#     РОЖдЕнИЕ
#
#     my_swapcase(осьминог)
#
#     ОсЬмИнОг
