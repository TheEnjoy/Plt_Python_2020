# %% [markdown]
# # Основы программирования в Python
#
# *Светлана Жучкова, НИУ ВШЭ*
#
# ## Семинар 6

# %% [markdown]
# ### Задача 1 (созидательная)
# Прочитайте описание данных (ниже) и создайте датафрейм на основе этого описания тремя разными способами:
# 1. датафрейм из списка списков
# * датафрейм из словаря
# * пустой датафрейм, который вы заполните в следующем порядке: сначала всю первую строку, затем весь последний столбец, а оставшиеся три ячейки нужно заполнить отдельно друг от друга тремя различными способами
#
# *Описание данных:*
# Это будут вымышленные данные о весе (`weight`, в килограммах, тип `int`) и росте (`height`, в метрах, тип `float`) четырёх людей: Michael, Lolita, John, Harry, Claudia и Robert. Переменные должны располагаться по столбцам, люди - по строкам, в индексах должны находиться имена. Сами данные следующие:
# * Michael: 86 кг, 1.70 м
# * Lolita: 55 кг, 1.58 м
# * John: 92 кг, 2.00 м
# * Harry: 79 кг, 1.78 м
# * Claudia: 49 кг, 1.58 м
# * Robert: 85 кг, 1.80 м
#
# После создания датафрейма и заполнения его данными:
# 1. создайте переменную `bmi` -  индекс массы тела, рассчитанный по формуле и округлённый до двух знаков после запятой: $$bmi = \frac{weight}{height^2}$$
# 2. создайте переменную `bmi_category`, в которой каждому значению предыдущей переменной будет присвоена метка: если `bmi` меньше 18.5 - "недостаточная масса тела", от 18.5 до 24.99 - "норма", 25 и выше - "избыточная масса тела"
# 3. отберите тех персонажей, которые попали в категорию "норма". Сколько их?

# %% [markdown]
# ### Задача 2 (аналитическая)
# Импортируйте файл `StudentsPerformance.csv` в датафрейм `students` с помощью функции `read_csv()` из модуля `pandas`. Ответьте на следующие вопросы:
#
# 1. сколько столбцов и строк в этом файле?
# * есть ли пропуски в данных? по каким переменным?
# * сколько уникальных категорий имеют переменные, находящиеся в первых 5 столбцах?
# * каков наиболее распространённый уровень образования родителей студентов из этой базы?
# * по какому из тестов (последние три столбца) набран в среднем самый высокий балл?
# * каков уровень корреляции между баллами трёх тестов?
# * кто в среднем успешнее справился с тестом по математике - девочки или мальчики? (используйте логическую индексацию для отбора отдельно девочек и мальчиков)
# * кто в среднем успешнее справился с тестом по чтению - те, кто проходили курс подготовки, или те, кто не проходили? (используйте логическую индексацию, чтобы отобрать отдельно тех и других)
# * создайте новую переменную `overall_score`, в которой будет находиться средний балл по всем трём тестам для каждого студента
# * создайте новую переменную `mathematician`, в которой будут находиться сведения о том, что студент в тесте по математике набрал баллов больше, чем в тесте по чтению (1 - если так, 0 - иначе; подсказка: скорее всего, вам понадобится создать ещё одну промежуточную переменную). Какой процент таких студентов находится в этой выборке?
